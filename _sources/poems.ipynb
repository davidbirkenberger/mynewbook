# %%
import pandas as pd

# %%
df = pd.read_csv(r'K:\python\poems\POetryFoundationData.csv', index_col=0)
df.head()
# Out:
#                                                Title  \
# 0  \r\r\n                    Objects Used to Prop...
# 1  \r\r\n                    The New Church\r\r\n...
# 2  \r\r\n                    Look for Me\r\r\n   ...
# 3  \r\r\n                    Wild Life\r\r\n     ...
# 4  \r\r\n                    Umbrella\r\r\n      ...
#
#                                                 Poem              Poet Tags
# 0  \r\r\nDog bone, stapler,\r\r\ncribbage board, ...  Michelle Menting  NaN
# 1  \r\r\nThe old cupola glinted above the clouds,...     Lucia Cherciu  NaN
# 2  \r\r\nLook for me under the hood\r\r\nof that ...        Ted Kooser  NaN
# 3  \r\r\nBehind the silo, the Mother Rabbit\r\r\n...   Grace Cavalieri  NaN
# 4  \r\r\nWhen I push your button\r\r\nyou fly off...      Connie Wanek  NaN

# %%
Poets = df["Poet"].to_list()
Poets
# Out:
# ['Michelle Menting',
#  'Lucia Cherciu',
#  'Ted Kooser',
#  'Grace Cavalieri',
#  'Connie Wanek',
#  "January Gill O'Neil",
#  'Joy Harjo',
#  'Joy Harjo',
#  'John Ashbery',
#  'Simone White',
#  'Heid E. Erdrich',
#  'Sarah White',
#  'Judith Harris',
#  'Kelly Madigan',
#  'Cathryn Essinger',
#  'P. Ivan Young',
#  'Truong Tran',
#  'Truong Tran',
#  'Debora Greger',
#  'Debora Greger',
#  'James Tate',
#  'Barbara Ras',
#  'Barbara Ras',
#  'Barbara Ras',
#  'Eugene Gloria',
#  'Eugene Gloria',
#  'Michael Gessner',
#  'Michael Gessner',
#  'Michael Gessner',
#  'Michael Gessner',
#  'Indran Amirthanayagam',
#  'Indran Amirthanayagam',
#  'Indran Amirthanayagam',
#  'Indran Amirthanayagam',
#  'Indran Amirthanayagam',
#  'Tao Lin',
#  'Tao Lin',
#  'Tao Lin',
#  'Margarita Engle',
#  'Margarita Engle',
#  'Margarita Engle',
#  'Margarita Engle',
#  'Quan Barry',
#  'Quan Barry',
#  'Quan Barry',
#  'Quan Barry',
#  'Quan Barry',
#  'Quan Barry',
#  'Quan Barry',
# ...

# %%
from bs4 import BeautifulSoup
import requests
import json

metadata = []
for i in df["Poet"]:
    Poet = Poets[i]
    Poet_lower = Poet.lower().split()
    final_poet = Poet_lower[0] + "-" + Poet_lower[1]
    base_url = "https://www.poetryfoundation.org/poets/"
    final_url = base_url + final_poet
    source_code = requests.get(final_url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    birthday_raw = soup.find("span", {"class":"c-txt c-txt_poetMeta"})
    print(birthday_raw)
# Out:
# None
# None
# <span class="c-txt c-txt_poetMeta">b. 1939</span>
# <span class="c-txt c-txt_poetMeta">b. 1932</span>
# <span class="c-txt c-txt_poetMeta">b. 1952</span>
# None
# <span class="c-txt c-txt_poetMeta">b. 1951</span>
# <span class="c-txt c-txt_poetMeta">b. 1951</span>
# <span class="c-txt c-txt_poetMeta">1927–2017</span>
# None
# None
# None
# None
# None
# None
# None
# <span class="c-txt c-txt_poetMeta">b. 1969</span>
# <span class="c-txt c-txt_poetMeta">b. 1969</span>
# <span class="c-txt c-txt_poetMeta">b. 1949</span>
# <span class="c-txt c-txt_poetMeta">b. 1949</span>
